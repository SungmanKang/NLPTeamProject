# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from datasets import load_dataset, load_metric
import numpy as np
from bertram import BertramWrapper
from transformers import AutoModelForSequenceClassification, AutoModel, AutoTokenizer, AutoConfig, DebertaForMaskedLM, DebertaTokenizer, DebertaForSequenceClassification

#

# %%
import glob

# absolute path to search all text files inside a specific folder
path = r'./training/train*.txt'
files = glob.glob(path)
print(files)
# Out:
# ['./training/train.bucket11.txt', './training/train.bucket16.txt', './training/train.bucket6.txt', './training/train.bucket4.txt', './training/train.bucket10.txt', './training/train.bucket7.txt', './training/train.bucket14.txt', './training/train.bucket24.txt', './training/train.bucket15.txt', './training/train.bucket1.txt', './training/train.bucket13.txt', './training/train.bucket17.txt', './training/train.bucket18.txt', './training/train.bucket12.txt', './training/train.bucket8.txt', './training/train.bucket3.txt', './training/train.bucket22.txt', './training/train.bucket23.txt', './training/train.bucket21.txt', './training/train.bucket2.txt', './training/train.bucket5.txt', './training/train.bucket0.txt', './training/train.bucket9.txt', './training/train.bucket19.txt', './training/train.bucket20.txt']

# %%
WordContextDict = {}

# %%
for file in files:
    loop_file = open(file, "r")
    loop_data = loop_file.readlines()
    
    for line in loop_data:
        line_list = line.split("\t")
        if line_list[0] not in WordContextDict.keys():
            WordContextDict[line_list[0]] = line_list[1:]

# %%
dataset = load_dataset("csv", data_files={"train": "./SST-2/train.csv", "validation": "./SST-2/dev.csv"})
metric = load_metric('glue', "sst2")

#
# Out:
# Using custom data configuration default-7d7b8bae96a2e227
# Found cached dataset csv (/home/rcorkil2/.cache/huggingface/datasets/csv/default-7d7b8bae96a2e227/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
#   0%|          | 0/2 [00:00<?, ?it/s]
# /home/rcorkil2/.conda/envs/base_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate

# %%
bertram_deberta = BertramWrapper('./outputs/DeBERTa_fused_trained-e1', device=device) #Sun ignore
# Out:
# 2022-11-27 17:55:18,394 - INFO - ngram_models - Found 712 ngrams with min count 4 and (nmin,nmax)=(3,5), first 10: ['UNK', 'PAD', 'ed<S>', 'ng<S>', 'ing', 'er<S>', 'ing<S>', 'on<S>', '<S>co', 'ion'], last 10: ['tly', 'tly<S>', 'cor', 'anc', 'ance', 'ance<S>', '<S>des', 'des', 'sio', 'sion']
# 2022-11-27 17:55:18,397 - INFO - utils - RYANRYANRYANLoading embeddings from ./fcm/wordEmbeddings/glove.6B.300d.txt
# 2022-11-27 18:22:54,477 - INFO - utils - Done loading embeddings
# Some weights of the model checkpoint at ./outputs/DeBERTa_fused_trained-e1 were not used when initializing BertramForDeBERTa: ['deberta.embeddings.word_embeddings.embedding.weight']
# - This IS expected if you are initializing BertramForDeBERTa from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertramForDeBERTa from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertramForDeBERTa were not initialized from the model checkpoint at ./outputs/DeBERTa_fused_trained-e1 and are newly initialized: ['deberta.embeddings.word_embeddings.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2022-11-27 18:22:57,678 - INFO - bertram - Reloading with do_setup=True because of missing keys: {'missing_keys': ['deberta.embeddings.word_embeddings.weight'], 'unexpected_keys': ['deberta.embeddings.word_embeddings.embedding.weight'], 'mismatched_keys': [], 'error_msgs': []}

# %%
model = DebertaForSequenceClassification.from_pretrained('microsoft/deberta-base') #do this
tokenizer = DebertaTokenizer.from_pretrained('microsoft/deberta-base') # do this
 
    
#ignore this 
words_with_contexts = WordContextDict

bertram_deberta.add_word_vectors_to_model(words_with_contexts, tokenizer, model)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-base were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head
- INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:07,690 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:07,690 - INFO - bertram - caught
# 2022-11-27 18:44:07,691 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:08,200 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:08,201 - INFO - bertram - caught
# 2022-11-27 18:44:08,202 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:10,988 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:10,989 - INFO - bertram - caught
# 2022-11-27 18:44:10,989 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:14,377 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:14,377 - INFO - bertram - caught
# 2022-11-27 18:44:14,378 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:14,826 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:14,826 - INFO - bertram - caught
# 2022-11-27 18:44:14,827 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:15,774 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:15,774 - INFO - bertram - caught
# 2022-11-27 18:44:15,775 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:18,134 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:18,134 - INFO - bertram - caught
# 2022-11-27 18:44:18,135 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:19,262 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:19,262 - INFO - bertram - caught
# 2022-11-27 18:44:19,263 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:22,660 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:22,661 - INFO - bertram - caught
# 2022-11-27 18:44:22,661 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:23,282 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:23,282 - INFO - bertram - caught
# 2022-11-27 18:44:23,283 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:24,444 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:24,444 - INFO - bertram - caught
# 2022-11-27 18:44:24,445 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:25,991 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:25,992 - INFO - bertram - caught
# 2022-11-27 18:44:25,993 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:26,971 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:26,972 - INFO - bertram - caught
# 2022-11-27 18:44:26,972 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:27,671 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:27,671 - INFO - bertram - caught
# 2022-11-27 18:44:27,672 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:29,677 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:29,678 - INFO - bertram - caught
# 2022-11-27 18:44:29,678 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:30,418 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:30,420 - INFO - bertram - caught
# 2022-11-27 18:44:30,422 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:31,082 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:31,084 - INFO - bertram - caught
# 2022-11-27 18:44:31,086 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:31,728 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:31,730 - INFO - bertram - caught
# 2022-11-27 18:44:31,731 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:32,384 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:32,386 - INFO - bertram - caught
# 2022-11-27 18:44:32,387 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:35,772 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:35,774 - INFO - bertram - caught
# 2022-11-27 18:44:35,775 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:36,167 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:36,169 - INFO - bertram - caught
# 2022-11-27 18:44:36,170 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:36,648 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:36,650 - INFO - bertram - caught
# 2022-11-27 18:44:36,652 - INFO - bertram - <class 'torch.Tensor'>
# 2022-11-27 18:44:37,155 - INFO - bertram - <class 'tuple'>
# 2022-11-27 18:44:37,157 - INFO - bertram - caught
# 2022-11-27 18:44:37,158 - INFO - bertram - <class 'torch.Tensor'>

# %%
model.to(device=device)
# Out:
# DebertaForSequenceClassification(
#   (deberta): DebertaModel(
#     (embeddings): DebertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=0)
#       (LayerNorm): DebertaLayerNorm()
#       (dropout): StableDropout()
#     )
#     (encoder): DebertaEncoder(
#       (layer): ModuleList(
#         (0): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (1): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (2): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (3): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (4): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (5): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (6): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (7): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (8): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (9): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (10): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#         (11): DebertaLayer(
#           (attention): DebertaAttention(
#             (self): DisentangledSelfAttention(
#               (in_proj): Linear(in_features=768, out_features=2304, bias=False)
#               (pos_dropout): StableDropout()
#               (pos_proj): Linear(in_features=768, out_features=768, bias=False)
#               (pos_q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): StableDropout()
#             )
#             (output): DebertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): DebertaLayerNorm()
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): DebertaLayerNorm()
#             (dropout): StableDropout()
#           )
#         )
#       )
#       (rel_embeddings): Embedding(1024, 768)
#     )
#   )
#   (pooler): ContextPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): StableDropout()
#   )
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): StableDropout()
# )

# %% [raw]
# #ignore this whole cell
# from transformers import AutoModelForSequenceClassification, AutoModel, AutoTokenizer, AutoConfig
#
#
# BERTtokenizer = AutoTokenizer.from_pretrained('bert-base-uncased', use_fast=True)
# BERTRAMconfig = AutoConfig.from_pretrained('./outputs/BERT_fused_trained/')
# BERTRAMmodel = AutoModelForSequenceClassification.from_config(BERTRAMconfig)
#
# RoBERTatokenizer = AutoTokenizer.from_pretrained('roberta-base', use_fast=True)
# RoBERTRAMaconfig = AutoConfig.from_pretrained('./outputs/RoBERTa_fused_trained/')
# RoBERTRAMamodel = AutoModelForSequenceClassification.from_config(RoBERTRAMaconfig)
#
# DeBERTatokenizer = AutoTokenizer.from_pretrained('microsoft/deberta-base', use_fast=True)
# DeBERTRAMaconfig = AutoConfig.from_pretrained('./outputs/DeBERTa_fused_trained/')
# DeBERTRAMamodel = AutoModelForSequenceClassification.from_config(DeBERTRAMaconfig)
#
# #BERTRAMmodel.to(device=device)

# %%
task_to_keys = {
    "sst2": ("sentence", None),
}

sentence1_key = "sentence"
sentence2_key = None

print(f"Sentence: {dataset['train'][0][sentence1_key]}")

    
def preprocess_function(examples):
    return tokenizer(examples[sentence1_key], truncation=True)


encoded_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Sentence: hide new secretions from the parental units
#   0%|          | 0/68 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
model_name="DeBERTRAMa"
task = "sst2"

# %%
import numpy as np
from transformers import Trainer
from datasets import load_metric
from transformers import TrainingArguments

training_args = TrainingArguments(
    evaluation_strategy="epoch",
    logging_steps=30,
    output_dir=f"{model_name}-finetuned-{task}",
    save_strategy = "epoch",
    learning_rate=2e-5,
    #learning_rate=0.001,
    per_device_train_batch_size=10,
    per_device_eval_batch_size=10,
)

metric = load_metric("accuracy")

#def compute_metrics(eval_pred):
#    logits, labels = eval_pred
#    predictions = np.argmax(logits, axis=-1)
#    return metric.compute(predictions=predictions, references=labels)

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    if task != "stsb":
        predictions = np.argmax(predictions, axis=1)
    else:
        predictions = predictions[:, 0]
    return metric.compute(predictions=predictions, references=labels)

trainer = Trainer(
    args=training_args,
    model=model,
    train_dataset=encoded_dataset['train'],
    eval_dataset=encoded_dataset['validation'],
    compute_metrics=compute_metrics,
    tokenizer=tokenizer
)

# %% [raw]
# import numpy as np
# from transformers import Trainer
# from datasets import load_metric
# from transformers import TrainingArguments
#
# training_args = TrainingArguments(
#     evaluation_strategy="epoch",
#     logging_steps=30,
#     output_dir=f"{model_name}-finetuned-{task}",
#     save_strategy = "epoch",
#     learning_rate=2e-5,
#     #learning_rate=0.001,
#     per_device_train_batch_size=5,
#     per_device_eval_batch_size=7,
# )
#
# metric = load_metric("accuracy")
#
# #def compute_metrics(eval_pred):
# #    logits, labels = eval_pred
# #    predictions = np.argmax(logits, axis=-1)
# #    return metric.compute(predictions=predictions, references=labels)
#
# def compute_metrics(eval_pred):
#     predictions, labels = eval_pred
#     if task != "stsb":
#         predictions = np.argmax(predictions, axis=1)
#     else:
#         predictions = predictions[:, 0]
#     return metric.compute(predictions=predictions, references=labels)
#
# BERTRAMtrainer = Trainer(
#     args=training_args,
#     model=BERTRAMmodel,
#     train_dataset=encoded_dataset['train'],
#     eval_dataset=encoded_dataset['validation'],
#     compute_metrics=compute_metrics,
#     tokenizer=BERTtokenizer
# )
#
# RoBERTRAMatrainer = Trainer(
#     args=training_args,
#     model=RoBERTRAMamodel,
#     train_dataset=dataset['train'],
#     eval_dataset=dataset['validation'],
#     compute_metrics=compute_metrics,
#     tokenizer=RoBERTatokenizer
# )
#
# DeBERTRAMatrainer = Trainer(
#     args=training_args,
#     model=DeBERTRAMamodel,
#     train_dataset=dataset['train'],
#     eval_dataset=dataset['validation'],
#     compute_metrics=compute_metrics,
#     tokenizer=DeBERTatokenizer
# )

# %%
encoded_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['sentence', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 872
#     })
# })

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DebertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DebertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 67349
#   Num Epochs = 3
#   Instantaneous batch size per device = 10
#   Total train batch size (w. parallel, distributed & accumulation) = 10
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20205
#   Number of trainable parameters = 140035586
#     <div>
#
#       <progress value='20205' max='20205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20205/20205 1:03:00, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.084700</td>
#       <td>0.324601</td>
#       <td>0.941514</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.028000</td>
#       <td>0.324601</td>
#       <td>0.941514</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.054500</td>
#       <td>0.324601</td>
#       <td>0.941514</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DebertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DebertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 10
# Saving model checkpoint to DeBERTRAMa-finetuned-sst2/checkpoint-6735
# Configuration saved in DeBERTRAMa-finetuned-sst2/checkpoint-6735/config.json
# Model weights saved in DeBERTRAMa-finetuned-sst2/checkpoint-6735/pytorch_model.bin
# tokenizer config file saved in DeBERTRAMa-finetuned-sst2/checkpoint-6735/tokenizer_config.json
# Special tokens file saved in DeBERTRAMa-finetuned-sst2/checkpoint-6735/special_tokens_map.json
# added tokens file saved in DeBERTRAMa-finetuned-sst2/checkpoint-6735/added_tokens.json
# The following columns in the evaluation set don't have a corresponding argument in `DebertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DebertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 10
# Saving model checkpoint to DeBERTRAMa-finetuned-sst2/checkpoint-13470
# Configuration saved in DeBERTRAMa-finetuned-sst2/checkpoint-13470/config.json
# Model weights saved in DeBERTRAMa-finetuned-sst2/checkpoint-13470/pytorch_model.bin
# tokenizer config file saved in DeBERTRAMa-finetuned-sst2/checkpoint-13470/tokenizer_config.json
# Special tokens file saved in DeBERTRAMa-finetuned-sst2/checkpoint-13470/special_tokens_map.json
# added tokens file saved in DeBERTRAMa-finetuned-sst2/checkpoint-13470/added_tokens.json
# The following columns in the evaluation set don't have a corresponding argument in `DebertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DebertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 10
# Saving model checkpoint to DeBERTRAMa-finetuned-sst2/checkpoint-20205
# Configuration saved in DeBERTRAMa-finetuned-sst2/checkpoint-20205/config.json
# Model weights saved in DeBERTRAMa-finetuned-sst2/checkpoint-20205/pytorch_model.bin
# tokenizer config file saved in DeBERTRAMa-finetuned-sst2/checkpoint-20205/tokenizer_config.json
# Special tokens file saved in DeBERTRAMa-finetuned-sst2/checkpoint-20205/special_tokens_map.json
# added tokens file saved in DeBERTRAMa-finetuned-sst2/checkpoint-20205/added_tokens.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=20205, training_loss=0.07434363544238023, metrics={'train_runtime': 3780.7872, 'train_samples_per_second': 53.44, 'train_steps_per_second': 5.344, 'total_flos': 3913626734210772.0, 'train_loss': 0.07434363544238023, 'epoch': 3.0})
