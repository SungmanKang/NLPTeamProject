# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from datasets import load_dataset, load_metric
import numpy as np
from bertram import BertramWrapper
from transformers import AutoModelForSequenceClassification, AutoModel, AutoTokenizer, AutoConfig, RobertaForMaskedLM, RobertaTokenizer, RobertaForSequenceClassification

#

# %%
import glob

# absolute path to search all text files inside a specific folder
path = r'./training/train*.txt'
files = glob.glob(path)
print(files)
# Out:
# ['./training/train.bucket11.txt', './training/train.bucket16.txt', './training/train.bucket6.txt', './training/train.bucket4.txt', './training/train.bucket10.txt', './training/train.bucket7.txt', './training/train.bucket14.txt', './training/train.bucket24.txt', './training/train.bucket15.txt', './training/train.bucket1.txt', './training/train.bucket13.txt', './training/train.bucket17.txt', './training/train.bucket18.txt', './training/train.bucket12.txt', './training/train.bucket8.txt', './training/train.bucket3.txt', './training/train.bucket22.txt', './training/train.bucket23.txt', './training/train.bucket21.txt', './training/train.bucket2.txt', './training/train.bucket5.txt', './training/train.bucket0.txt', './training/train.bucket9.txt', './training/train.bucket19.txt', './training/train.bucket20.txt']

# %%
WordContextDict = {}

# %%
for file in files:
    loop_file = open(file, "r")
    loop_data = loop_file.readlines()
    
    for line in loop_data:
        line_list = line.split("\t")
        if line_list[0] not in WordContextDict.keys():
            WordContextDict[line_list[0]] = line_list[1:]

# %%
dataset = load_dataset("csv", data_files={"train": "./SST-2/train.csv", "validation": "./SST-2/dev.csv"})
metric = load_metric('glue', "sst2")

#
# Out:
# Using custom data configuration default-7d7b8bae96a2e227
# Found cached dataset csv (/home/rcorkil2/.cache/huggingface/datasets/csv/default-7d7b8bae96a2e227/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
#   0%|          | 0/2 [00:00<?, ?it/s]
# /home/rcorkil2/.conda/envs/base_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate

# %%
bertram_roberta = BertramWrapper('./outputs/RoBERTa_fused_trained-e1', device=device) #Sun ignore
# Out:
# 2022-11-27 19:56:49,486 - INFO - ngram_models - Found 712 ngrams with min count 4 and (nmin,nmax)=(3,5), first 10: ['UNK', 'PAD', 'ed<S>', 'ng<S>', 'ing', 'er<S>', 'ing<S>', 'on<S>', '<S>co', 'ion'], last 10: ['tly', 'tly<S>', 'cor', 'anc', 'ance', 'ance<S>', '<S>des', 'des', 'sio', 'sion']
# 2022-11-27 19:56:49,488 - INFO - utils - RYANRYANRYANLoading embeddings from ./fcm/wordEmbeddings/glove.6B.300d.txt
# 2022-11-27 20:26:55,418 - INFO - utils - Done loading embeddings
# Some weights of the model checkpoint at ./outputs/RoBERTa_fused_trained-e1 were not used when initializing BertramForRoberta: ['roberta.embeddings.word_embeddings.embedding.weight']
# - This IS expected if you are initializing BertramForRoberta from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertramForRoberta from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertramForRoberta were not initialized from the model checkpoint at ./outputs/RoBERTa_fused_trained-e1 and are newly initialized: ['roberta.embeddings.word_embeddings.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2022-11-27 20:26:59,092 - INFO - bertram - Reloading with do_setup=True because of missing keys: {'missing_keys': ['roberta.embeddings.word_embeddings.weight'], 'unexpected_keys': ['roberta.embeddings.word_embeddings.embedding.weight'], 'mismatched_keys': [], 'error_msgs': []}

# %%
model = RobertaForSequenceClassification.from_pretrained('roberta-base') #do this
tokenizer = RobertaTokenizer.from_pretrained('roberta-base') # do this
 
    
#ignore this 
words_with_contexts = WordContextDict

bertram_roberta.add_word_vectors_to_model(words_with_contexts, tokenizer, model)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
#ignore this whole cell
from transformers import AutoModelForSequenceClassification, AutoModel, AutoTokenizer, AutoConfig


BERTtokenizer = AutoTokenizer.from_pretrained('bert-base-uncased', use_fast=True)
BERTRAMconfig = AutoConfig.from_pretrained('./outputs/BERT_fused_trained/')
BERTRAMmodel = AutoModelForSequenceClassification.from_config(BERTRAMconfig)

RoBERTatokenizer = AutoTokenizer.from_pretrained('roberta-base', use_fast=True)
RoBERTRAMaconfig = AutoConfig.from_pretrained('./outputs/RoBERTa_fused_trained/')
RoBERTRAMamodel = AutoModelForSequenceClassification.from_config(RoBERTRAMaconfig)

DeBERTatokenizer = AutoTokenizer.from_pretrained('microsoft/deberta-base', use_fast=True)
DeBERTRAMaconfig = AutoConfig.from_pretrained('./outputs/DeBERTa_fused_trained/')
DeBERTRAMamodel = AutoModelForSequenceClassification.from_config(DeBERTRAMaconfig)

#BERTRAMmodel.to(device=device)

# %%
task_to_keys = {
    "sst2": ("sentence", None),
}

sentence1_key = "sentence"
sentence2_key = None

print(f"Sentence: {dataset['train'][0][sentence1_key]}")

    
def preprocess_function(examples):
    return tokenizer(examples[sentence1_key], truncation=True)


encoded_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Sentence: hide new secretions from the parental units
#   0%|          | 0/68 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
model_name="RoBERTRAMa"
task = "sst2"

# %%
import numpy as np
from transformers import Trainer
from datasets import load_metric
from transformers import TrainingArguments

training_args = TrainingArguments(
    evaluation_strategy="epoch",
    logging_steps=30,
    output_dir=f"{model_name}-finetuned-{task}",
    save_strategy = "epoch",
    learning_rate=2e-5,
    #learning_rate=0.001,
    per_device_train_batch_size=10,
    per_device_eval_batch_size=10,
)

metric = load_metric("accuracy")

#def compute_metrics(eval_pred):
#    logits, labels = eval_pred
#    predictions = np.argmax(logits, axis=-1)
#    return metric.compute(predictions=predictions, references=labels)

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    if task != "stsb":
        predictions = np.argmax(predictions, axis=1)
    else:
        predictions = predictions[:, 0]
    return metric.compute(predictions=predictions, references=labels)

trainer = Trainer(
    args=training_args,
    model=model,
    train_dataset=encoded_dataset['train'],
    eval_dataset=encoded_dataset['validation'],
    compute_metrics=compute_metrics,
    tokenizer=tokenizer
)

# %% [raw]
# import numpy as np
# from transformers import Trainer
# from datasets import load_metric
# from transformers import TrainingArguments
#
# training_args = TrainingArguments(
#     evaluation_strategy="epoch",
#     logging_steps=30,
#     output_dir=f"{model_name}-finetuned-{task}",
#     save_strategy = "epoch",
#     learning_rate=2e-5,
#     #learning_rate=0.001,
#     per_device_train_batch_size=5,
#     per_device_eval_batch_size=7,
# )
#
# metric = load_metric("accuracy")
#
# #def compute_metrics(eval_pred):
# #    logits, labels = eval_pred
# #    predictions = np.argmax(logits, axis=-1)
# #    return metric.compute(predictions=predictions, references=labels)
#
# def compute_metrics(eval_pred):
#     predictions, labels = eval_pred
#     if task != "stsb":
#         predictions = np.argmax(predictions, axis=1)
#     else:
#         predictions = predictions[:, 0]
#     return metric.compute(predictions=predictions, references=labels)
#
# BERTRAMtrainer = Trainer(
#     args=training_args,
#     model=BERTRAMmodel,
#     train_dataset=encoded_dataset['train'],
#     eval_dataset=encoded_dataset['validation'],
#     compute_metrics=compute_metrics,
#     tokenizer=BERTtokenizer
# )
#
# RoBERTRAMatrainer = Trainer(
#     args=training_args,
#     model=RoBERTRAMamodel,
#     train_dataset=dataset['train'],
#     eval_dataset=dataset['validation'],
#     compute_metrics=compute_metrics,
#     tokenizer=RoBERTatokenizer
# )
#
# DeBERTRAMatrainer = Trainer(
#     args=training_args,
#     model=DeBERTRAMamodel,
#     train_dataset=dataset['train'],
#     eval_dataset=dataset['validation'],
#     compute_metrics=compute_metrics,
#     tokenizer=DeBERTatokenizer
# )

# %%
encoded_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['sentence', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 872
#     })
# })

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/rcorkil2/.conda/envs/base_env/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 67349
#   Num Epochs = 3
#   Instantaneous batch size per device = 10
#   Total train batch size (w. parallel, distributed & accumulation) = 10
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20205
#   Number of trainable parameters = 125488898
#     <div>
#
#       <progress value='20205' max='20205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20205/20205 28:11, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.194700</td>
#       <td>0.286936</td>
#       <td>0.925459</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.191300</td>
#       <td>0.318185</td>
#       <td>0.927752</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078500</td>
#       <td>0.334962</td>
#       <td>0.936927</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 10
# Saving model checkpoint to RoBERTRAMa-finetuned-sst2/checkpoint-6735
# Configuration saved in RoBERTRAMa-finetuned-sst2/checkpoint-6735/config.json
# Model weights saved in RoBERTRAMa-finetuned-sst2/checkpoint-6735/pytorch_model.bin
# tokenizer config file saved in RoBERTRAMa-finetuned-sst2/checkpoint-6735/tokenizer_config.json
# Special tokens file saved in RoBERTRAMa-finetuned-sst2/checkpoint-6735/special_tokens_map.json
# added tokens file saved in RoBERTRAMa-finetuned-sst2/checkpoint-6735/added_tokens.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 10
# Saving model checkpoint to RoBERTRAMa-finetuned-sst2/checkpoint-13470
# Configuration saved in RoBERTRAMa-finetuned-sst2/checkpoint-13470/config.json
# Model weights saved in RoBERTRAMa-finetuned-sst2/checkpoint-13470/pytorch_model.bin
# tokenizer config file saved in RoBERTRAMa-finetuned-sst2/checkpoint-13470/tokenizer_config.json
# Special tokens file saved in RoBERTRAMa-finetuned-sst2/checkpoint-13470/special_tokens_map.json
# added tokens file saved in RoBERTRAMa-finetuned-sst2/checkpoint-13470/added_tokens.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 10
# Saving model checkpoint to RoBERTRAMa-finetuned-sst2/checkpoint-20205
# Configuration saved in RoBERTRAMa-finetuned-sst2/checkpoint-20205/config.json
# Model weights saved in RoBERTRAMa-finetuned-sst2/checkpoint-20205/pytorch_model.bin
# tokenizer config file saved in RoBERTRAMa-finetuned-sst2/checkpoint-20205/tokenizer_config.json
# Special tokens file saved in RoBERTRAMa-finetuned-sst2/checkpoint-20205/special_tokens_map.json
# added tokens file saved in RoBERTRAMa-finetuned-sst2/checkpoint-20205/added_tokens.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=20205, training_loss=0.20967964056369487, metrics={'train_runtime': 1708.0665, 'train_samples_per_second': 118.29, 'train_steps_per_second': 11.829, 'total_flos': 3364014106636980.0, 'train_loss': 0.20967964056369487, 'epoch': 3.0})
